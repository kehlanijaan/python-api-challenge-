# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np. x_axis = 14.11, 19.71, 18.84, 23.56, 5.17, 24.62, 24.88, 23.17, 1.28
np. y_axis = 0, 0, 0, 0.35, 0.63, 0.74, 0.8, 0.89, 1.03
ax.set_xlabel('temperature')
ax.set_ylabel('wind speed')

#x ac
# Compute areas and colors
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

# %% [markdown]
# City with Max Temperature under 27 and wind speed less that 4.5 and cloudiness 0.

# %% [markdown]
# [115	cedar city	37.6775	-113.0619	14.11	49	0	0	US	1666108304]66

# %% [markdown]
# [128	half moon bay	37.4636	-122.4286	19.71	86	0	0	US	1666108312]

# %% [markdown]
# [488	pleasanton	37.6624	-121.8747	18.84	86	0	0	US	1666108325]

# %% [markdown]
# [240	tikaitnagar	26.95	81.5833	23.56	59	0	0.35	IN	1666108378]
#
# [268	chengde	40.9725	117.9361	5.17	26	0	0.63	CN	1666108395]
#
# [340	santa rosalia	27.3167	-112.2833	24.62	56	0	0.74	MX	1666108436]

# %% [markdown]
# [421	    stolac	43.0844	17.9575	24.88	68	0	0.8	BA	1666108483]
#
#
# [516	    guerrero negro	27.9769	-114.0611	23.17	68	0	0.89	MX	1666108537]
#
#
# [394	     quesnel	52.9999	-122.5029	1.28	93	0	1.03	CA	1666108467]
