# %%
import matplotlib.pyplot as plt
import numpy as np
Latitude = [18.3851, 58.0948, -42.7826, 42.097, 36.0564,-54.8, 42.6001, -24.8667, 66.9395, -21.3393, -22.8375, 59.7035, -3.2778, 58.4619, 77.484, -46.1927, 71.9667,
65.6145, 71.6872, -0.7393, -21.2078, 27.4763, -16.3494, -23.1203, 62.55, -35.3333, 48.3835, -20.3428, 39.8212, 16.3333, 35.4495, 54.1121, -33.9258, 58.2093,
-4.2, 70.6333, 48.035, 62.2266, -6.8844, 19.9333, 70.4692, -21.6403, 51.3813, -41.8697, 35.042, 22.075, 22.0371, 41.5946, -27.1833, -42.8794, 73.5069, 19.7297,
3.3333, 46.6166, -21.2, 4.9333, 61.6864, 66.4167, -33.0153, -33.65, -8.9266, 63.8424, 71.2906, 25.4833, -9.8, -34.4187, -38.0023, -17.7125, -34.7333,
-34.5322, -6.1761, -11.0267, 49.1667, 30.3333, 71.9167, 69.4058, 50.086, -24.2511, 57.1437, -20.4081, 56.1667, 21.3469, 53.1667, -33.8667, 32.767, 64.3833,
-31.2503, -21.3585, 32.6667, 50.7214, 37.1041, 52.0324, 59.7, 5.6667, 3.0707, 10.5669, 38.9342, 29.9576, -2.9248]
Temperature = [22.06, 13.3, 11.72, 5.77, 14.53, 8.81, 10.36, 20.02, 2.72, 22.82, 20.36, 8.94, 31.07, 5.63, -17.32, 2.89, -3.4, 2.39, -13.6, 22.98, 22.03, 12.15, 
38.35, 20.41, -15.51, 15.04, 4.66, 22.14, 12.84, 38.8, 9.12, 16.1, 20.61, 12.18, 21.12, -14.63, 13.39, 6.51, 25.24, 28.05, -5.87, 29.05, 16.84, 14.75, 7.11, 
22.99, 25.67, 9.6, 16.66, 11.92, -1.34, 26.27, 24.82, 23.49, 23.09, 32.02, 4.3, -8.08, 21.52, 11.67, 17.08, 7.26, -3.99, 24.62, 24.69, 21.56, 16.64, 26.69, 15.02,
19.14, 12.22, 27.1, 11.92, 25.41, -12.18, -0.21, 16.79, 18.69, 11.41, 22.16, 3.26, 21.66, 3.16, 11.24, 20.86, -4.14, 21.1, 22.77, 26.51, 0.06, 13.33, 16.31,
-4.99, 26.95, 27.47, 27.12, 11.11, 16.43, 31.07]
plt.scatter (Latitude, Temperature)
plt.style.use('dark_background')
ncolors = len(plt.rcParams['axes.prop_cycle'])
ax.set_xlabel('Latitude')
ax.set_ylabel('Temperature')
ax.set_title("Latitude vs Temperature")
plt.show()

# %%
# import matplotlib.pyplot as plt 
Latitude = [18.3851, 58.0948, -42.7826, 42.097, 36.0564, -54.8, 42.6001, -24.8667, 66.9395, -21.3393, -22.8375, 59.7035, -3.2778, 58.4619, 77.484]
Humidity = [35, 100, 58, 77, 48, 81, 74, 76, 98, 68, 86, 90, 51, 93, 74] 
plt.scatter(Latitude, Humidity)
plt.show()
import numpy as np 
#obtain m(slope) and b(intercept) of linear regression line
m, b = np.polyfit(Latitude, Humidity, 1)
#add linear regression line to scatter plot 
plt.plot(Latitude, m*(Latitude+b))

# %%
import matplotlib.pyplot as plt 
Latitude = [18.3851, 58.0948, -42.7826, 42.097, 36.0564, -54.8, 42.6001, -24.8667, 66.9395, -22.8375, -21.3393, 59.7035, -3.2778, 58.4619, 77.484]
Cloudiness = [21, 0, 12, 100, 59, 75, 29, 0, 100, 0, 96, 100, 34, 100, 86]
plt.scatter(Latitude, Cloudiness)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %%
#import matplotlib.pyplot as plt 
Latitude = [18.3851, 58.0948, -42.7826, 42.097, 36.0564, -54.8, 42.6001, -24.8667, 66.9395, -22.8375, -21.3393, 59.7035, -3.2778, 58.4619, 77.484]
WindSpeed = [2.6, 7.65, 1.34, 9.77, 1.2, 3.09, 2.1, 7.46, 3.79, 5.14, 4.69, 3.22, 8.09, 3.55, 3.36]
plt.scatter(Latitude, WindSpeed)
plt.xlabel("Latitude")
plt.ylabel("WindSpeed")
plt.show()
import numpy as np
#obtain m(slope) and b(intercept) of linear regression line 
m, b = np.polyfit(Latitude, WindSpeed, 1)
#add linear regression line to scatter plot 
plt.plot(Latitude, m*(Latitude+b))
plt.xlabel("Latitude")
plt.ylabel("WindSpeed")
# Out:
# Text(0, 0.5, 'WindSpeed')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = 18.3851, 58.0948, 42.097, 36.0564, 42.6001, 66.9395, 59.7035, 58.4619, 77.484
y = 22.06, 13.3, 5.77, 14.53, 10.36, 2.72, 8.94, 5.63, -17.32
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('temperature')
ax.set_title('Northern Hemisphere, Latitude vs Temperature')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = -42.7826, -54.8, -24.8667, -21.3393, -22.8375, -3.2778, -46.1927
y = 11.72, 8.81, 20.02, 22.82, 20.36, 31.07, 2.89

ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('temperature')
ax.set_title('Southern Hemisphere, Latitude vs Temperature')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = 18.3851, 58.0948, 42.097, 36.0564, 42.6001, 66.9395, 59.7035, 58.4619, 77.484
y = 35, 100, 77, 48, 74, 98, 90, 93, 74

ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('humidity')
ax.set_title('Northern Hemisphere, Latitude vs Humidity')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = -42.7826, -54.8, -24.8667, -21.3393, -22.8375, -3.2778, -46.1927
y = 58, 81, 76, 68, 86, 51, 96


ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('temperature')
ax.set_title('Southern Hemisphere, Latitude vs Humidity')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = 18.3851, 58.0948, 42.097, 36.0564, 42.6001, 66.9395, 59.7035, 58.4619, 77.484
y = 21, 0, 100, 59, 29, 100, 100, 100, 86


ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('cloudiness')
ax.set_title('Northern Hemisphere, Latitude vs Cloudiness')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = -42.7826, -54.8, -24.8667, -21.3393, -22.8375, -3.2778, -46.1927
y = 12, 75, 0, 0, 96, 34, 97



ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('cloudiness')
ax.set_title('Southern Hemisphere, Latitude vs Cloudiness')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = 18.3851, 58.0948, 42.097, 36.0564, 42.6001, 66.9395, 59.7035, 58.4619, 77.484
y = 2.6, 7.65, 9.77, 1.2, 2.1, 3.79, 3.22, 3.55, 3.36
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('wind speed')
ax.set_title('Northern Hemisphere, Latitude vs Wind Speed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')
fig, ax = plt.subplots()
x = -42.7826, -54.8, -24.8667, -21.3393, -22.8375, -3.2778, -46.1927
y = 7.65, 3.09, 7.46, 5.14, 4.69, 8.09, 1.36

ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('latitude')
ax.set_ylabel('wind speed')
ax.set_title('Southern Hemisphere, Latitude vs Wind Speed')
plt.show()
